# %% [markdown]
# задача - число сочетаний

# %%
def C(n,m):
    if n < 0 or m < 0:
        return 1
    if n == m or m == 0:
        return 0
    else:

# %%
def Function(a,b):
    Da = []
    Db = []
    while a % 2 == 0 or b % 2 == 0:
        if a % 2 == 0:
            if len(Da) == 0:
                Da.append(2)
            if b % 2 == 0:
                if len(Db) == 0:
                    Db.append(2)
                b //= 2
            if len(Db) > 0 and len(Da) > 0:
                return False
            p +=3
            while p * p <= a or p * p <= b:
                if a % p == 0:
                    if len(Da) == 0:
                        Da.append(p)
                    a //= p
                if b % p == 0:
                    if len(Db) == 0:
                        Db.append(p)
                    b //= p
    return True

# %%
N = int(input())
mxk = 0
k = 0
while N % 2 == 2:
    k += 1
    n //= 2
mxk = k
p = 3
while p * p <= N:
    k = 0
    while N % p == 0:
        N //= p
        k += 1
    p+= 2
    mxk = max(mxk, k)
if N > 1:
    mxk = max(mxk, 1)
print(mxk)
# Out:
# 4

# %%
a, b = map (int, input().split())
a, b = abs(a),abs(b)
while b != 0:
    a, b = b, a % b
print (a)
# Out:
# 2 2
