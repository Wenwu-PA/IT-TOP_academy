# %% [markdown]
# <center>work 21.11.2025</center>

# %%
def isPoly(S):
    for i in range(len(S)//2):
        if S[i]!=S[-(1+i)]:
            return False
    return True
with open("RussianLiterature.txt",'r',encoding="cp1251") as F:
    for S in F:
        S = S.split()[0]
        if len(S) > 4 and isPoly(S):
            print(S)

# %% [markdown]
# <center>словари</center>

# %%
Capitals - dict()
Capitals.keys() #получений значений по ключу

# %% [markdown]
# задача

# %%
N = int(input("counts students: "))
S = dict()
num = 0
while N >= num:
    surname,initials,school = input("<фамилия><инициалы><номер школы> ").split(" ")
    S[school] = S.get(school,0) + 1
    num += 1
S = sorted(S, key=S.get)
mn = S[school[0]]
i = 0
while S[school[i]] == mn:
    print(school[i])
    i += 1

# %% [markdown]
# задача

# %%
with open("Зоопарк.txt",'r') as F:
S = F.read().split( )

D = dict()
for animal in S:
    D[animal] = D.get(animal,0)+1
# Out:
# Running cells with 'Python 3.10.18' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Program Files/Salt Project/Salt/Scripts/python.exe" -m pip install ipykernel -U --user --force-reinstall'
