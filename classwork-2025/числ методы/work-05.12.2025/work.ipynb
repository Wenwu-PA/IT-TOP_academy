# %%
from fractions import fraction

f1 = fraction(3,4) #3/4
print (f1)

# %%
from decimal import Decimal

n = Decimal('311')
d = Decimal('99')
print (n/d)

# %%
from fractions import Fraction

milk = Fraction(1,3)
water = Fraction(1,4)
mesh = Fraction(1,2)
r_mesh = milk + water - mesh

print(r_mesh)
# Out:
# 1/12

# %%
money = int(input("input "))
m_first = Fraction(1,3) * money
m_two = Fraction(2,5) * money
m_tree = (money - m_first - m_two) / 2 
m_first += m_tree
print(m_first)
print(m_two)
print(m_tree)
# Out:
# 420000
# 360000
# 120000
