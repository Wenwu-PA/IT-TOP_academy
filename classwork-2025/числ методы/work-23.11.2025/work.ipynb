# %% [markdown]
# **первый урок**

# %%
F = open("in.txt").read()
F.close()
F.tell() // поиск на каком ты символе
F.seek(6) // перейти на какой то символ
F.readline() // читать строку

# %%
k = 0
with open("input.txt","r") as F:
    N = int(F.readline())
    for _ in range(N):
        n - int(F.readline())
        if n%3 == 0 and abs(n)%10 == 2:
            k+=1
with open ("output.txt","w") as F:
    F.write(str(k))

# %%
with open("classwork-2025/числ методы/24.txt","r") as F:
    S = F.readline()
    curlen = 1
    maxlen = 0
    for i in range(1,len(S)):
        if S[i] != S[i-1]:
            curlen += 1
            maxlen = max(curlen,maxlen)
        else:
            curlen = 0
print(maxlen)
